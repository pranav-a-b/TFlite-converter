# %%
import os
import tensorflow as tf
from tensorflow import keras 
print(tf.__version__)
# !pwd
# !ls
# Out:
# 2.8.0
# /content
# potato_model.h5  sample_data

# %%
Potato_model = tf.keras.models.load_model('potato_model.h5')
converter = tf.lite.TFLiteConverter.from_keras_model(Potato_model)
tflite_model = converter.convert()
open('Potato_model.tflite' , "wb").write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp51k38093/assets
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# 171068388
